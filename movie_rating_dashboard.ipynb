# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("F:/ProgrammingJavaPythonHtml/Year 2025/archive/movie.csv")
rating = pd.read_csv("F:/ProgrammingJavaPythonHtml/Year 2025/archive/rating.csv")

# %%
df.head(50)
# Out:
#     movieId                                              title  \
# 0         1                                   Toy Story (1995)
# 1         2                                     Jumanji (1995)
# 2         3                            Grumpier Old Men (1995)
# 3         4                           Waiting to Exhale (1995)
# 4         5                 Father of the Bride Part II (1995)
# 5         6                                        Heat (1995)
# 6         7                                     Sabrina (1995)
# 7         8                                Tom and Huck (1995)
# 8         9                                Sudden Death (1995)
# 9        10                                   GoldenEye (1995)
# 10       11                     American President, The (1995)
# 11       12                 Dracula: Dead and Loving It (1995)
# 12       13                                       Balto (1995)
# 13       14                                       Nixon (1995)
# 14       15                            Cutthroat Island (1995)
# 15       16                                      Casino (1995)
# 16       17                       Sense and Sensibility (1995)
# 17       18                                  Four Rooms (1995)
# 18       19              Ace Ventura: When Nature Calls (1995)
# 19       20                                 Money Train (1995)
# 20       21                                  Get Shorty (1995)
# 21       22                                     Copycat (1995)
# 22       23                                   Assassins (1995)
# 23       24                                      Powder (1995)
# 24       25                           Leaving Las Vegas (1995)
# 25       26                                     Othello (1995)
# 26       27                                Now and Then (1995)
# 27       28                                  Persuasion (1995)
# 28       29  City of Lost Children, The (Cité des enfants p...
# 29       30  Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# 30       31                             Dangerous Minds (1995)
# 31       32          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 32       33                            Wings of Courage (1995)
# 33       34                                        Babe (1995)
# 34       35                                  Carrington (1995)
# 35       36                            Dead Man Walking (1995)
# 36       37                      Across the Sea of Time (1995)
# 37       38                                It Takes Two (1995)
# 38       39                                    Clueless (1995)
# 39       40                    Cry, the Beloved Country (1995)
# 40       41                                 Richard III (1995)
# 41       42                             Dead Presidents (1995)
# 42       43                                 Restoration (1995)
# 43       44                               Mortal Kombat (1995)
# 44       45                                  To Die For (1995)
# 45       46               How to Make an American Quilt (1995)
# 46       47                        Seven (a.k.a. Se7en) (1995)
# 47       48                                  Pocahontas (1995)
# 48       49                       When Night Is Falling (1995)
# 49       50                         Usual Suspects, The (1995)
#
#                                          genres
# 0   Adventure|Animation|Children|Comedy|Fantasy
# 1                    Adventure|Children|Fantasy
# 2                                Comedy|Romance
# 3                          Comedy|Drama|Romance
# 4                                        Comedy
# 5                         Action|Crime|Thriller
# 6                                Comedy|Romance
# 7                            Adventure|Children
# 8                                        Action
# 9                     Action|Adventure|Thriller
# 10                         Comedy|Drama|Romance
# 11                                Comedy|Horror
# 12                 Adventure|Animation|Children
# 13                                        Drama
# 14                     Action|Adventure|Romance
# 15                                  Crime|Drama
# 16                                Drama|Romance
# 17                                       Comedy
# 18                                       Comedy
# 19           Action|Comedy|Crime|Drama|Thriller
# 20                        Comedy|Crime|Thriller
# 21          Crime|Drama|Horror|Mystery|Thriller
# 22                        Action|Crime|Thriller
# 23                                 Drama|Sci-Fi
# 24                                Drama|Romance
# 25                                        Drama
# 26                               Children|Drama
# 27                                Drama|Romance
# 28       Adventure|Drama|Fantasy|Mystery|Sci-Fi
# 29                                  Crime|Drama
# 30                                        Drama
# 31                      Mystery|Sci-Fi|Thriller
# 32                       Adventure|Romance|IMAX
# 33                               Children|Drama
# 34                                Drama|Romance
# 35                                  Crime|Drama
# 36                             Documentary|IMAX
# 37                              Children|Comedy
# 38                               Comedy|Romance
# 39                                        Drama
# 40                                    Drama|War
# 41                           Action|Crime|Drama
# 42                                        Drama
# 43                     Action|Adventure|Fantasy
# 44                        Comedy|Drama|Thriller
# 45                                Drama|Romance
# 46                             Mystery|Thriller
# 47     Animation|Children|Drama|Musical|Romance
# 48                                Drama|Romance
# 49                       Crime|Mystery|Thriller

# %%
df.isnull().sum()
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
df = df.drop_duplicates(subset='title')

# %%
np.mean(rating['rating'])
# Out:
# np.float64(3.5255285642993797)

# %%
np.max(rating['rating'])
# Out:
# np.float64(5.0)

# %%
np.min(rating['rating'])
# Out:
# np.float64(0.5)

# %%
genre_counts = df['genres'].value_counts()
genre_counts
# Out:
# genres
# Drama                                                  4520
# Comedy                                                 2294
# Documentary                                            1942
# Comedy|Drama                                           1264
# Drama|Romance                                          1075
#                                                        ...
# Action|Animation|Children|Fantasy|Sci-Fi                  1
# Adventure|Animation|Children|Fantasy|Mystery|Sci-Fi       1
# Documentary|Romance|War                                   1
# Comedy|Mystery|Romance|Thriller                           1
# Adventure|Drama|Fantasy|Mystery|Sci-Fi                    1
# Name: count, Length: 1342, dtype: int64

# %%
rating.head(50)
# Out:
#     userId  movieId  rating            timestamp
# 0        1        2     3.5  2005-04-02 23:53:47
# 1        1       29     3.5  2005-04-02 23:31:16
# 2        1       32     3.5  2005-04-02 23:33:39
# 3        1       47     3.5  2005-04-02 23:32:07
# 4        1       50     3.5  2005-04-02 23:29:40
# 5        1      112     3.5  2004-09-10 03:09:00
# 6        1      151     4.0  2004-09-10 03:08:54
# 7        1      223     4.0  2005-04-02 23:46:13
# 8        1      253     4.0  2005-04-02 23:35:40
# 9        1      260     4.0  2005-04-02 23:33:46
# 10       1      293     4.0  2005-04-02 23:31:43
# 11       1      296     4.0  2005-04-02 23:32:47
# 12       1      318     4.0  2005-04-02 23:33:18
# 13       1      337     3.5  2004-09-10 03:08:29
# 14       1      367     3.5  2005-04-02 23:53:00
# 15       1      541     4.0  2005-04-02 23:30:03
# 16       1      589     3.5  2005-04-02 23:45:57
# 17       1      593     3.5  2005-04-02 23:31:01
# 18       1      653     3.0  2004-09-10 03:08:11
# 19       1      919     3.5  2004-09-10 03:07:01
# 20       1      924     3.5  2004-09-10 03:06:38
# 21       1     1009     3.5  2005-04-02 23:53:33
# 22       1     1036     4.0  2005-04-02 23:44:40
# 23       1     1079     4.0  2004-09-10 03:07:45
# 24       1     1080     3.5  2005-04-02 23:42:55
# 25       1     1089     3.5  2005-04-02 23:31:09
# 26       1     1090     4.0  2005-04-02 23:44:13
# 27       1     1097     4.0  2005-04-02 23:48:21
# 28       1     1136     3.5  2005-04-02 23:30:09
# 29       1     1193     3.5  2005-04-02 23:31:30
# 30       1     1196     4.5  2005-04-02 23:32:22
# 31       1     1198     4.5  2005-04-02 23:30:24
# 32       1     1200     4.0  2005-04-02 23:29:20
# 33       1     1201     3.0  2005-04-02 23:30:42
# 34       1     1208     3.5  2005-04-02 23:33:35
# 35       1     1214     4.0  2004-09-10 03:12:57
# 36       1     1215     4.0  2004-09-10 03:14:42
# 37       1     1217     3.5  2005-04-02 23:33:30
# 38       1     1219     4.0  2004-09-10 03:13:14
# 39       1     1222     3.5  2005-04-02 23:30:37
# 40       1     1240     4.0  2005-04-02 23:43:21
# 41       1     1243     3.0  2005-04-02 23:46:07
# 42       1     1246     3.5  2004-09-10 03:09:19
# 43       1     1249     4.0  2005-04-02 23:43:02
# 44       1     1258     4.0  2004-09-10 03:13:14
# 45       1     1259     4.0  2005-04-02 23:44:00
# 46       1     1261     3.5  2004-09-10 03:15:13
# 47       1     1262     3.5  2005-04-02 23:32:15
# 48       1     1266     4.0  2005-04-02 23:42:51
# 49       1     1278     4.0  2004-09-10 03:13:06

# %%
merged_data = pd.merge(rating, df, on="movieId")

# %%
merged_data
# Out:
#           userId  movieId  rating            timestamp  \
# 0              1        2     3.5  2005-04-02 23:53:47
# 1              1       29     3.5  2005-04-02 23:31:16
# 2              1       32     3.5  2005-04-02 23:33:39
# 3              1       47     3.5  2005-04-02 23:32:07
# 4              1       50     3.5  2005-04-02 23:29:40
# ...          ...      ...     ...                  ...
# 20000258  138493    68954     4.5  2009-11-13 15:42:00
# 20000259  138493    69526     4.5  2009-12-03 18:31:48
# 20000260  138493    69644     3.0  2009-12-07 18:10:57
# 20000261  138493    70286     5.0  2009-11-13 15:42:24
# 20000262  138493    71619     2.5  2009-10-17 20:25:36
#
#                                                       title  \
# 0                                            Jumanji (1995)
# 1         City of Lost Children, The (Cité des enfants p...
# 2                 Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 3                               Seven (a.k.a. Se7en) (1995)
# 4                                Usual Suspects, The (1995)
# ...                                                     ...
# 20000258                                          Up (2009)
# 20000259         Transformers: Revenge of the Fallen (2009)
# 20000260              Ice Age: Dawn of the Dinosaurs (2009)
# 20000261                                  District 9 (2009)
# 20000262      Coco Before Chanel (Coco avant Chanel) (2009)
#
#                                                      genres
# 0                                Adventure|Children|Fantasy
# 1                    Adventure|Drama|Fantasy|Mystery|Sci-Fi
# 2                                   Mystery|Sci-Fi|Thriller
# 3                                          Mystery|Thriller
# 4                                    Crime|Mystery|Thriller
# ...                                                     ...
# 20000258                 Adventure|Animation|Children|Drama
# 20000259                       Action|Adventure|Sci-Fi|IMAX
# 20000260  Action|Adventure|Animation|Children|Comedy|Rom...
# 20000261                            Mystery|Sci-Fi|Thriller
# 20000262                                              Drama
#
# [20000263 rows x 6 columns]

# %%
merged_data.isnull().sum()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# title        0
# genres       0
# dtype: int64

# %%
merged_data['release_year'] = merged_data['title'].str.extract(r"\((\d{4})\)").astype(float)

# %%
top_movies = merged_data.groupby('title')['rating'].mean().sort_values(ascending=False).head(10)
top_movies
# Out:
# title
# Hollywood and The Pentagon: A Dangerous Liaison (2003)                       5.0
# Hijacking Catastrophe: 9/11, Fear & the Selling of American Empire (2004)    5.0
# 1971 (2014)                                                                  5.0
# Human Behavior Experiments, The (2006)                                       5.0
# Poison (1951)                                                                5.0
# Blue Swallow (Cheong yeon) (2005)                                            5.0
# Bandaged (2009)                                                              5.0
# Foster Brothers, The (Süt kardesler) (1976)                                  5.0
# Abendland (2011)                                                             5.0
# Oranges (2004)                                                               5.0
# Name: rating, dtype: float64

# %%
genre_counts = merged_data['genres'].value_counts()
genre_counts
# Out:
# genres
# Drama                                               1467402
# Comedy                                              1316161
# Comedy|Romance                                       793252
# Comedy|Drama                                         656474
# Drama|Romance                                        644626
#                                                      ...
# Children|Drama|Thriller                                   1
# Action|Adventure|Crime|Drama|Sci-Fi|Thriller|War          1
# Action|Comedy|Crime|Fantasy|Thriller                      1
# Adventure|Children|Comedy|Documentary|Drama               1
# Action|Adventure|Comedy|Fantasy|Sci-Fi                    1
# Name: count, Length: 1329, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
top_rated_movies = merged_data.groupby('title')['rating'].mean().sort_values(ascending=False).head(10)

# Bar chart
top_rated_movies.plot(kind='bar', color='green')
plt.title("Top 10 Movies by Average Rating")
plt.xlabel("Movie")
plt.ylabel("Average Rating")
plt.xticks(rotation=45)
plt.show()

# %%
# Filter movies by genre
genre = "Action"  # Example genre
genre_filtered = merged_data[merged_data['genres'].str.contains(genre, na=False)]
genre_filtered
# Out:
#           userId  movieId  rating            timestamp  \
# 5              1      112     3.5  2004-09-10 03:09:00
# 6              1      151     4.0  2004-09-10 03:08:54
# 9              1      260     4.0  2005-04-02 23:33:46
# 10             1      293     4.0  2005-04-02 23:31:43
# 14             1      367     3.5  2005-04-02 23:53:00
# ...          ...      ...     ...                  ...
# 20000254  138493    61160     4.0  2009-11-16 16:55:37
# 20000255  138493    65682     4.5  2009-10-17 21:52:53
# 20000257  138493    68319     4.5  2009-12-07 18:15:20
# 20000259  138493    69526     4.5  2009-12-03 18:31:48
# 20000260  138493    69644     3.0  2009-12-07 18:10:57
#
#                                                       title  \
# 5                Rumble in the Bronx (Hont faan kui) (1995)
# 6                                            Rob Roy (1995)
# 9                 Star Wars: Episode IV - A New Hope (1977)
# 10        Léon: The Professional (a.k.a. The Professiona...
# 14                                         Mask, The (1994)
# ...                                                     ...
# 20000254                   Star Wars: The Clone Wars (2008)
# 20000255              Underworld: Rise of the Lycans (2009)
# 20000257                    X-Men Origins: Wolverine (2009)
# 20000259         Transformers: Revenge of the Fallen (2009)
# 20000260              Ice Age: Dawn of the Dinosaurs (2009)
#
#                                                      genres  release_year
# 5                             Action|Adventure|Comedy|Crime        1995.0
# 6                                  Action|Drama|Romance|War        1995.0
# 9                                   Action|Adventure|Sci-Fi        1977.0
# 10                              Action|Crime|Drama|Thriller        1994.0
# 14                              Action|Comedy|Crime|Fantasy        1994.0
# ...                                                     ...           ...
# 20000254                  Action|Adventure|Animation|Sci-Fi        2008.0
# 20000255                     Action|Fantasy|Horror|Thriller        2009.0
# 20000257                             Action|Sci-Fi|Thriller        2009.0
# 20000259                       Action|Adventure|Sci-Fi|IMAX        2009.0
# 20000260  Action|Adventure|Animation|Children|Comedy|Rom...        2009.0
#
# [5614208 rows x 7 columns]

# %%
most_rated_movies = merged_data.groupby('title').size().sort_values(ascending=False).head(10)
most_rated_movies
# Out:
# title
# Pulp Fiction (1994)                          67310
# Forrest Gump (1994)                          66172
# Shawshank Redemption, The (1994)             63366
# Silence of the Lambs, The (1991)             63299
# Jurassic Park (1993)                         59715
# Star Wars: Episode IV - A New Hope (1977)    54502
# Braveheart (1995)                            53769
# Terminator 2: Judgment Day (1991)            52244
# Matrix, The (1999)                           51334
# Schindler's List (1993)                      50054
# dtype: int64

# %%
merged_data.to_csv("cleaned_movie_data.csv", index=False)

# %%
import streamlit as st

# Load the merged data
data = pd.read_csv("cleaned_movie_data.csv")

st.title("Movie Ratings Dashboard")

# Filter by Genre
genre = st.selectbox("Select Genre", data['genres'].unique())
filtered_data = data[data['genres'].str.contains(genre, na=False)]

st.write(f"Top Movies in {genre}")
st.dataframe(filtered_data[['title', 'rating']].sort_values(by='rating', ascending=False).head(10))
# Out:
# 2025-01-06 20:57:38.176 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-06 20:57:39.049
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\archit vaishnav\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-01-06 20:57:39.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-06 20:57:43.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-06 20:57:43.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-06 20:57:43.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-06 20:57:43.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-06 20:57:43.751 Session state does not function when running a script without `streamlit run`
# 2025-01-06 20:57:43.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-06 20:57:43.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-06 20:58:13.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-06 20:58:13.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-06 20:58:13.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-06 20:58:13.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-06 20:58:14.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-06 20:58:14.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
streamlit run app.py
# Out:
#   Cell In[41], line 1
#     streamlit run app.py
#               ^
# SyntaxError: invalid syntax
